# %% [markdown]
# # Credit Risk Assessment & Loan Default Prediction

# %% [markdown]
# #### Bussiness Problem: Financial institutions need to assess borrower risk before approving loans. This project predicts the likelihood of loan default using machine learning models.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

pd.set_option('display.float_format', lambda x: '{:.2f}'.format(x))
np.set_printoptions(suppress=True)

# %% [markdown]
# # Data Gathering And Preprocessing:

# %%
# Load datasets
df_customers=pd.read_csv("customers.csv")
df_loans=pd.read_csv("loans.csv")
df_bureau=pd.read_csv("bureau_data.csv")

# %%
df_customers.shape,df_loans.shape,df_bureau.shape
# Out:
# ((50000, 12), (50000, 15), (50000, 8))

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cust_id                   50000 non-null  object
#  1   age                       50000 non-null  int64
#  2   gender                    50000 non-null  object
#  3   marital_status            50000 non-null  object
#  4   employment_status         50000 non-null  object
#  5   income                    50000 non-null  int64
#  6   number_of_dependants      50000 non-null  int64
#  7   residence_type            49938 non-null  object
#  8   years_at_current_address  50000 non-null  int64
#  9   city                      50000 non-null  object
#  10  state                     50000 non-null  object
#  11  zipcode                   50000 non-null  int64
# dtypes: int64(5), object(7)
# memory usage: 4.6+ MB

# %%
df_customers.head(3)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
# 2                     3          Owned                        24  Kolkata
#
#          state  zipcode
# 0        Delhi   110001
# 1   Tamil Nadu   600001
# 2  West Bengal   700001

# %%
df_loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   loan_id                      50000 non-null  object
#  1   cust_id                      50000 non-null  object
#  2   loan_purpose                 50000 non-null  object
#  3   loan_type                    50000 non-null  object
#  4   sanction_amount              50000 non-null  int64
#  5   loan_amount                  50000 non-null  int64
#  6   processing_fee               50000 non-null  float64
#  7   gst                          50000 non-null  int64
#  8   net_disbursement             50000 non-null  int64
#  9   loan_tenure_months           50000 non-null  int64
#  10  principal_outstanding        50000 non-null  int64
#  11  bank_balance_at_application  50000 non-null  int64
#  12  disbursal_date               50000 non-null  object
#  13  installment_start_dt         50000 non-null  object
#  14  default                      50000 non-null  bool
# dtypes: bool(1), float64(1), int64(7), object(6)
# memory usage: 5.4+ MB

# %%
df_loans.head(3)
# Out:
#   loan_id cust_id loan_purpose  loan_type  sanction_amount  loan_amount  \
# 0  L00001  C00001         Auto    Secured          3004000      2467000
# 1  L00002  C00002         Home    Secured          4161000      3883000
# 2  L00003  C00003     Personal  Unsecured          2401000      2170000
#
#    processing_fee     gst  net_disbursement  loan_tenure_months  \
# 0        49340.00  444060           1973600                  33
# 1        77660.00  698940           3106400                  30
# 2        43400.00  390600           1736000                  21
#
#    principal_outstanding  bank_balance_at_application disbursal_date  \
# 0                1630408                       873386     2019-07-24
# 1                 709309                       464100     2019-07-24
# 2                1562399                      1476042     2019-07-24
#
#   installment_start_dt  default
# 0           2019-08-10    False
# 1           2019-08-15    False
# 2           2019-08-21    False

# %%
df_bureau.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   cust_id                    50000 non-null  object
#  1   number_of_open_accounts    50000 non-null  int64
#  2   number_of_closed_accounts  50000 non-null  int64
#  3   total_loan_months          50000 non-null  int64
#  4   delinquent_months          50000 non-null  int64
#  5   total_dpd                  50000 non-null  int64
#  6   enquiry_count              50000 non-null  int64
#  7   credit_utilization_ratio   50000 non-null  int64
# dtypes: int64(7), object(1)
# memory usage: 3.1+ MB

# %%
df_bureau.head(3)
# Out:
#   cust_id  number_of_open_accounts  number_of_closed_accounts  \
# 0  C00001                        1                          1
# 1  C00002                        3                          1
# 2  C00003                        2                          1
#
#    total_loan_months  delinquent_months  total_dpd  enquiry_count  \
# 0                 42                  0          0              3
# 1                 96                 12         60              5
# 2                 82                 24        147              6
#
#    credit_utilization_ratio
# 0                         7
# 1                         4
# 2                        58

# %%
df=pd.merge(df_customers,df_loans,on='cust_id')
df.head(3)
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
#
#    number_of_dependants residence_type  years_at_current_address     city  \
# 0                     3          Owned                        27    Delhi
# 1                     3          Owned                         4  Chennai
# 2                     3          Owned                        24  Kolkata
#
#    ... loan_amount  processing_fee     gst net_disbursement  \
# 0  ...     2467000        49340.00  444060          1973600
# 1  ...     3883000        77660.00  698940          3106400
# 2  ...     2170000        43400.00  390600          1736000
#
#   loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# 0                 33                1630408                       873386
# 1                 30                 709309                       464100
# 2                 21                1562399                      1476042
#
#    disbursal_date  installment_start_dt  default
# 0      2019-07-24            2019-08-10    False
# 1      2019-07-24            2019-08-15    False
# 2      2019-07-24            2019-08-21    False
#
# [3 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cust_id                      50000 non-null  object
#  1   age                          50000 non-null  int64
#  2   gender                       50000 non-null  object
#  3   marital_status               50000 non-null  object
#  4   employment_status            50000 non-null  object
#  5   income                       50000 non-null  int64
#  6   number_of_dependants         50000 non-null  int64
#  7   residence_type               49938 non-null  object
#  8   years_at_current_address     50000 non-null  int64
#  9   city                         50000 non-null  object
#  10  state                        50000 non-null  object
#  11  zipcode                      50000 non-null  int64
#  12  loan_id                      50000 non-null  object
#  13  loan_purpose                 50000 non-null  object
#  14  loan_type                    50000 non-null  object
#  15  sanction_amount              50000 non-null  int64
#  16  loan_amount                  50000 non-null  int64
#  17  processing_fee               50000 non-null  float64
#  18  gst                          50000 non-null  int64
#  19  net_disbursement             50000 non-null  int64
#  20  loan_tenure_months           50000 non-null  int64
#  21  principal_outstanding        50000 non-null  int64
#  22  bank_balance_at_application  50000 non-null  int64
#  23  disbursal_date               50000 non-null  object
#  24  installment_start_dt         50000 non-null  object
#  25  default                      50000 non-null  bool
# dtypes: bool(1), float64(1), int64(12), object(12)
# memory usage: 9.6+ MB

# %%
df=pd.merge(df,df_bureau,on='cust_id')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cust_id                      50000 non-null  object
#  1   age                          50000 non-null  int64
#  2   gender                       50000 non-null  object
#  3   marital_status               50000 non-null  object
#  4   employment_status            50000 non-null  object
#  5   income                       50000 non-null  int64
#  6   number_of_dependants         50000 non-null  int64
#  7   residence_type               49938 non-null  object
#  8   years_at_current_address     50000 non-null  int64
#  9   city                         50000 non-null  object
#  10  state                        50000 non-null  object
#  11  zipcode                      50000 non-null  int64
#  12  loan_id                      50000 non-null  object
#  13  loan_purpose                 50000 non-null  object
#  14  loan_type                    50000 non-null  object
#  15  sanction_amount              50000 non-null  int64
#  16  loan_amount                  50000 non-null  int64
#  17  processing_fee               50000 non-null  float64
#  18  gst                          50000 non-null  int64
#  19  net_disbursement             50000 non-null  int64
#  20  loan_tenure_months           50000 non-null  int64
#  21  principal_outstanding        50000 non-null  int64
#  22  bank_balance_at_application  50000 non-null  int64
#  23  disbursal_date               50000 non-null  object
#  24  installment_start_dt         50000 non-null  object
#  25  default                      50000 non-null  bool
#  26  number_of_open_accounts      50000 non-null  int64
#  27  number_of_closed_accounts    50000 non-null  int64
#  28  total_loan_months            50000 non-null  int64
#  29  delinquent_months            50000 non-null  int64
#  30  total_dpd                    50000 non-null  int64
#  31  enquiry_count                50000 non-null  int64
#  32  credit_utilization_ratio     50000 non-null  int64
# dtypes: bool(1), float64(1), int64(19), object(12)
# memory usage: 12.3+ MB

# %%
df['default']=df['default'].astype(int)
df.default.value_counts()
# Out:
# default
# 0    45703
# 1     4297
# Name: count, dtype: int64

# %%
X=df.drop("default",axis="columns")
y=df['default']

X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y,test_size=0.25,random_state=42)

df_train=pd.concat([X_train,y_train],axis="columns")
df_test=pd.concat([X_test,y_test],axis="columns")

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37500 entries, 12746 to 37784
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cust_id                      37500 non-null  object
#  1   age                          37500 non-null  int64
#  2   gender                       37500 non-null  object
#  3   marital_status               37500 non-null  object
#  4   employment_status            37500 non-null  object
#  5   income                       37500 non-null  int64
#  6   number_of_dependants         37500 non-null  int64
#  7   residence_type               37453 non-null  object
#  8   years_at_current_address     37500 non-null  int64
#  9   city                         37500 non-null  object
#  10  state                        37500 non-null  object
#  11  zipcode                      37500 non-null  int64
#  12  loan_id                      37500 non-null  object
#  13  loan_purpose                 37500 non-null  object
#  14  loan_type                    37500 non-null  object
#  15  sanction_amount              37500 non-null  int64
#  16  loan_amount                  37500 non-null  int64
#  17  processing_fee               37500 non-null  float64
#  18  gst                          37500 non-null  int64
#  19  net_disbursement             37500 non-null  int64
#  20  loan_tenure_months           37500 non-null  int64
#  21  principal_outstanding        37500 non-null  int64
#  22  bank_balance_at_application  37500 non-null  int64
#  23  disbursal_date               37500 non-null  object
#  24  installment_start_dt         37500 non-null  object
#  25  number_of_open_accounts      37500 non-null  int64
#  26  number_of_closed_accounts    37500 non-null  int64
#  27  total_loan_months            37500 non-null  int64
#  28  delinquent_months            37500 non-null  int64
#  29  total_dpd                    37500 non-null  int64
#  30  enquiry_count                37500 non-null  int64
#  31  credit_utilization_ratio     37500 non-null  int64
#  32  default                      37500 non-null  int64
# dtypes: float64(1), int64(20), object(12)
# memory usage: 9.7+ MB

# %%
df_train.shape
# Out:
# (37500, 33)

# %%
df_train.isna().sum()
# Out:
# cust_id                         0
# age                             0
# gender                          0
# marital_status                  0
# employment_status               0
# income                          0
# number_of_dependants            0
# residence_type                 47
# years_at_current_address        0
# city                            0
# state                           0
# zipcode                         0
# loan_id                         0
# loan_purpose                    0
# loan_type                       0
# sanction_amount                 0
# loan_amount                     0
# processing_fee                  0
# gst                             0
# net_disbursement                0
# loan_tenure_months              0
# principal_outstanding           0
# bank_balance_at_application     0
# disbursal_date                  0
# installment_start_dt            0
# number_of_open_accounts         0
# number_of_closed_accounts       0
# total_loan_months               0
# delinquent_months               0
# total_dpd                       0
# enquiry_count                   0
# credit_utilization_ratio        0
# default                         0
# dtype: int64

# %%
df_train.residence_type.unique()
# Out:
# array(['Owned', 'Mortgage', 'Rented', nan], dtype=object)

# %%
mode_residence=df_train.residence_type.mode()[0]
mode_residence
# Out:
# 'Owned'

# %%
df_train["residence_type"]=df_train["residence_type"].fillna(mode_residence)
df_test["residence_type"]=df_test["residence_type"].fillna(mode_residence)

# %%
df_train.isna().sum()
# Out:
# cust_id                        0
# age                            0
# gender                         0
# marital_status                 0
# employment_status              0
# income                         0
# number_of_dependants           0
# residence_type                 0
# years_at_current_address       0
# city                           0
# state                          0
# zipcode                        0
# loan_id                        0
# loan_purpose                   0
# loan_type                      0
# sanction_amount                0
# loan_amount                    0
# processing_fee                 0
# gst                            0
# net_disbursement               0
# loan_tenure_months             0
# principal_outstanding          0
# bank_balance_at_application    0
# disbursal_date                 0
# installment_start_dt           0
# number_of_open_accounts        0
# number_of_closed_accounts      0
# total_loan_months              0
# delinquent_months              0
# total_dpd                      0
# enquiry_count                  0
# credit_utilization_ratio       0
# default                        0
# dtype: int64

# %%
df_train.residence_type.unique()
# Out:
# array(['Owned', 'Mortgage', 'Rented'], dtype=object)

# %%
df_train.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_train.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default'],
#       dtype='object')

# %%
df_train.dtypes
# Out:
# cust_id                         object
# age                              int64
# gender                          object
# marital_status                  object
# employment_status               object
# income                           int64
# number_of_dependants             int64
# residence_type                  object
# years_at_current_address         int64
# city                            object
# state                           object
# zipcode                          int64
# loan_id                         object
# loan_purpose                    object
# loan_type                       object
# sanction_amount                  int64
# loan_amount                      int64
# processing_fee                 float64
# gst                              int64
# net_disbursement                 int64
# loan_tenure_months               int64
# principal_outstanding            int64
# bank_balance_at_application      int64
# disbursal_date                  object
# installment_start_dt            object
# number_of_open_accounts          int64
# number_of_closed_accounts        int64
# total_loan_months                int64
# delinquent_months                int64
# total_dpd                        int64
# enquiry_count                    int64
# credit_utilization_ratio         int64
# default                          int64
# dtype: object

# %%
df_train.shape
# Out:
# (37500, 33)

# %%
columns_continuous = ['age','income','number_of_dependants','years_at_current_address', 
                      'sanction_amount','loan_amount','processing_fee','gst','net_disbursement', 
                      'loan_tenure_months','principal_outstanding', 'bank_balance_at_application',
                      'number_of_open_accounts','number_of_closed_accounts','total_loan_months','delinquent_months',
                       'total_dpd','enquiry_count','credit_utilization_ratio']

columns_categorical = ['gender','marital_status','employment_status','residence_type','city', 
                       'state','zipcode','loan_purpose','loan_type','default']

# %%
import matplotlib.pyplot as plt
df_train[columns_continuous].plot(
    kind="box", 
    subplots=True, 
    layout=( (len(columns_continuous)+3)//4 , 4 ), 
    figsize=(20, 10)
)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

num_plots=len(columns_continuous)
num_cols=4   # number of plots per row
num_rows=math.ceil(num_plots/num_cols)  # ceiling division for rows

plt.figure(figsize=(20,5*num_rows))
for i,col in enumerate(columns_continuous,1):
    plt.subplot(num_rows,num_cols,i)
    sns.boxplot(x=df_train[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

num_plots=len(columns_continuous)
num_cols=4   # number of plots per row
num_rows=math.ceil(num_plots/num_cols)  # ceiling division for rows

plt.figure(figsize=(20,5*num_rows))
for i,col in enumerate(columns_continuous,1):
    plt.subplot(num_rows,num_cols,i)
    sns.histplot(df_train[col],bins=30,kde=False)  # histogram
    plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Outlier Removal-Processing Fees:

# %%
df_train.processing_fee.describe()
# Out:
# count     37500.00
# mean      80290.68
# std      113128.14
# min           0.00
# 25%       19220.00
# 50%       44600.00
# 75%       92420.00
# max     5293543.52
# Name: processing_fee, dtype: float64

# %%
df_train[(df_train.processing_fee/df_train.loan_amount)>0.03][["loan_amount","processing_fee"]]
# Out:
#        loan_amount  processing_fee
# 23981      2234000      2669791.02
# 28174       966000      1214492.67
# 47089      1738000      1858964.77
# 29305      2616000      3036378.01
# 9898       3626000      5293543.52

# %%
df_train_1=df_train[df_train.processing_fee/df_train.loan_amount<0.03].copy()
df_train_1.shape
# Out:
# (37488, 33)

# %%
df_test=df_test[df_test.processing_fee/df_test.loan_amount<0.03].copy()
df_test.shape
# Out:
# (12497, 33)

# %% [markdown]
# # Using 2 important business rules for data validation:

# %% [markdown]
# ## Rule1:GST should not be more than 20%
# ## Rule 2:Net disbursement should not be higher than loan_amount

# %%
#Rule1:GST should not be more than 20%:
df_train_1[(df_train_1.gst/df_train_1.loan_amount)>0.2].shape
# Out:
# (0, 33)

# %%
#Rule 2:Net disbursement should not be higher than loan_amount:
df_train_1[df_train_1.net_disbursement>df_train_1.loan_amount].shape
# Out:
# (0, 33)

# %%
columns_categorical
# Out:
# ['gender',
#  'marital_status',
#  'employment_status',
#  'residence_type',
#  'city',
#  'state',
#  'zipcode',
#  'loan_purpose',
#  'loan_type',
#  'default']

# %%
for col in columns_categorical:
    print(col,"------------->",df_train_1[col].unique())
# Out:
# gender -------------> ['M' 'F']
# marital_status -------------> ['Married' 'Single']
# employment_status -------------> ['Self-Employed' 'Salaried']
# residence_type -------------> ['Owned' 'Mortgage' 'Rented']
# city -------------> ['Hyderabad' 'Mumbai' 'Chennai' 'Bangalore' 'Pune' 'Kolkata' 'Ahmedabad'
#  'Delhi' 'Lucknow' 'Jaipur']
# state -------------> ['Telangana' 'Maharashtra' 'Tamil Nadu' 'Karnataka' 'West Bengal'
#  'Gujarat' 'Delhi' 'Uttar Pradesh' 'Rajasthan']
# zipcode -------------> [500001 400001 600001 560001 411001 700001 380001 110001 226001 302001]
# loan_purpose -------------> ['Home' 'Education' 'Personal' 'Auto' 'Personaal']
# loan_type -------------> ['Secured' 'Unsecured']
# default -------------> [0 1]

# %%
#Fixing erroes in Loan Purpose Column:
df_train_1['loan_purpose']=df_train_1['loan_purpose'].replace('Personaal','Personal')
df_train_1['loan_purpose'].unique()
# Out:
# array(['Home', 'Education', 'Personal', 'Auto'], dtype=object)

# %%
df_test['loan_purpose']=df_test['loan_purpose'].replace('Personaal','Personal')
df_test['loan_purpose'].unique()
# Out:
# array(['Home', 'Education', 'Auto', 'Personal'], dtype=object)

# %% [markdown]
# # EDA:

# %%
columns_continuous
# Out:
# ['age',
#  'income',
#  'number_of_dependants',
#  'years_at_current_address',
#  'sanction_amount',
#  'loan_amount',
#  'processing_fee',
#  'gst',
#  'net_disbursement',
#  'loan_tenure_months',
#  'principal_outstanding',
#  'bank_balance_at_application',
#  'number_of_open_accounts',
#  'number_of_closed_accounts',
#  'total_loan_months',
#  'delinquent_months',
#  'total_dpd',
#  'enquiry_count',
#  'credit_utilization_ratio']

# %%
# Exploring the age column:
df_train_1.groupby("default")['age'].describe()
# Out:
#            count  mean  std   min   25%   50%   75%   max
# default
# 0       34265.00 39.77 9.88 18.00 33.00 40.00 46.00 70.00
# 1        3223.00 37.12 9.29 18.00 31.00 37.00 44.00 70.00

# %%
plt.figure(figsize=(5,4))
sns.kdeplot(df_train_1['age'][df_train_1['default']==0],fill=True,label='default=0')
sns.kdeplot(df_train_1['age'][df_train_1['default']==1],fill=True,label='default=1')
plt.title(f"Age KDE Plot with Hue by default")
plt.legend()
plt.show()

# %%
# Kde for all the columns:
plt.figure(figsize=(20,20))# Width,height in inches
for i,col in enumerate(columns_continuous):
    plt.subplot(6,4,i+1)#1 row,4columns,ithsubplot
    sns.kdeplot(df_train_1[col][df_train_1['default']==0],fill=True,label='default=0')
    sns.kdeplot(df_train_1[col][df_train_1['default']==1],fill=True,label='default=1')
    plt.title(col)        
    plt.xlabel('')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Feature Engineering:

# %%
df_train_1[["loan_amount", "income"]].head(3)
# Out:
#        loan_amount    income
# 12746     23442000  11327000
# 32495      1149000    715000
# 43675     11296000   3195000

# %%
df_train_1['loan_to_income']=round(df_train_1['loan_amount']/df_train_1['income'],2)
df_train_1['loan_to_income'].describe()
# Out:
# count   37488.00
# mean        1.56
# std         0.97
# min         0.30
# 25%         0.77
# 50%         1.16
# 75%         2.46
# max         4.57
# Name: loan_to_income, dtype: float64

# %%
df_test['loan_to_income']=round(df_test['loan_amount']/df_test['income'],2)

# %%
plt.figure(figsize=(8,4))
sns.kdeplot(df_train_1['loan_to_income'][df_train_1['default'] == 0],fill=True,label='default=0')
sns.kdeplot(df_train_1['loan_to_income'][df_train_1['default'] == 1],fill=True,label='default=1')
plt.title(f"Loan to Income Ratio (LTI) KDE Plot with Hue by default")
plt.legend()
plt.show()

# %%
# Generating Delinquency Ratio:
df_train_1['delinquency_ratio']=(df_train_1['delinquent_months']*100/df_train_1['total_loan_months']).round(1)
df_test['delinquency_ratio']=(df_test['delinquent_months']*100/df_test['total_loan_months']).round(1)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['delinquency_ratio'][df_train_1['default']==0],fill=True,label='default=0')
sns.kdeplot(df_train_1['delinquency_ratio'][df_train_1['default']==1],fill=True,label='default=1')
plt.title(f"Delinquency Ratio KDE Plot with Hue by default")
plt.legend()
plt.show()

# %%
# Generating Avg Dpd Per Delinquency:
df_train_1['avg_dpd_per_delinquency']=np.where(
    df_train_1['delinquent_months']!=0,(df_train_1['total_dpd']/df_train_1['delinquent_months']).round(1)
    ,0
)

# %%
df_test['avg_dpd_per_delinquency']=np.where(
    df_test['delinquent_months']!=0,(df_test['total_dpd']/df_test['delinquent_months']).round(1)
    ,0
)

# %%
plt.figure(figsize=(8,4))
sns.kdeplot(df_train_1['avg_dpd_per_delinquency'][df_train_1['default']==0],fill=True,label='default=0')
sns.kdeplot(df_train_1['avg_dpd_per_delinquency'][df_train_1['default']==1],fill=True,label='default=1')
plt.title(f"Avg DPD Per Delinquency Ratio KDE Plot with Hue by default")
plt.legend()
plt.show()

# %%
# Remove the columns that are just unique ids and dont have influence on target:
df_train_1.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default',
#        'loan_to_income', 'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
df_train_2=df_train_1.drop(['cust_id','loan_id'],axis="columns")

# %%
df_test=df_test.drop(['cust_id','loan_id'],axis="columns")

# %%
# Removing Columns that Bussiness Contact persons asked us to remove:

df_train_3=df_train_2.drop(['disbursal_date','installment_start_dt','loan_amount','income', 
                              'total_loan_months','delinquent_months','total_dpd'],axis="columns")

# %%
df_test=df_test.drop(['disbursal_date','installment_start_dt','loan_amount','income', 
                              'total_loan_months','delinquent_months','total_dpd'],axis="columns")

# %%
df_train_3.columns
# Out:
# Index(['age', 'gender', 'marital_status', 'employment_status',
#        'number_of_dependants', 'residence_type', 'years_at_current_address',
#        'city', 'state', 'zipcode', 'loan_purpose', 'loan_type',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
df_train_3.select_dtypes(['int64','float64']).columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
# VIF to measure multi co-linearity:

X_train=df_train_3.drop('default',axis='columns')
y_train=df_train_3['default']

# %%
from sklearn.preprocessing import MinMaxScaler
cols_to_scale=X_train.select_dtypes(['int64','float64']).columns
scaler=MinMaxScaler()
X_train[cols_to_scale]=scaler.fit_transform(X_train[cols_to_scale])

# %%
X_train.describe()
# Out:
#            age  number_of_dependants  years_at_current_address  zipcode  \
# count 37488.00              37488.00                  37488.00 37488.00
# mean      0.41                  0.39                      0.50     0.52
# std       0.19                  0.31                      0.30     0.29
# min       0.00                  0.00                      0.00     0.00
# 25%       0.29                  0.00                      0.23     0.33
# 50%       0.40                  0.40                      0.50     0.49
# 75%       0.54                  0.60                      0.77     0.76
# max       1.00                  1.00                      1.00     1.00
#
#        sanction_amount  processing_fee      gst  net_disbursement  \
# count         37488.00        37488.00 37488.00          37488.00
# mean              0.09            0.08     0.08              0.08
# std               0.12            0.11     0.11              0.11
# min               0.00            0.00     0.00              0.00
# 25%               0.02            0.02     0.02              0.02
# 50%               0.05            0.05     0.05              0.05
# 75%               0.10            0.10     0.10              0.10
# max               1.00            1.00     1.00              1.00
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count            37488.00               37488.00                     37488.00
# mean                 0.38                   0.26                         0.12
# std                  0.23                   0.24                         0.13
# min                  0.00                   0.00                         0.00
# 25%                  0.19                   0.08                         0.03
# 50%                  0.34                   0.19                         0.08
# 75%                  0.55                   0.35                         0.16
# max                  1.00                   1.00                         1.00
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count                 37488.00                   37488.00       37488.00
# mean                      0.50                       0.50           0.50
# std                       0.37                       0.41           0.25
# min                       0.00                       0.00           0.00
# 25%                       0.00                       0.00           0.38
# 50%                       0.67                       0.50           0.50
# 75%                       1.00                       1.00           0.62
# max                       1.00                       1.00           1.00
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# count                  37488.00        37488.00           37488.00
# mean                       0.44            0.29               0.10
# std                        0.30            0.23               0.17
# min                        0.00            0.00               0.00
# 25%                        0.18            0.11               0.00
# 50%                        0.39            0.20               0.04
# 75%                        0.68            0.51               0.13
# max                        1.00            1.00               1.00
#
#        avg_dpd_per_delinquency
# count                 37488.00
# mean                      0.33
# std                       0.29
# min                       0.00
# 25%                       0.00
# 50%                       0.43
# 75%                       0.57
# max                       1.00

# %%
X_test=df_test.drop('default',axis='columns')
y_test=df_test['default']

X_test[cols_to_scale]=scaler.transform(X_test[cols_to_scale])
X_test.describe()
# Out:
#            age  number_of_dependants  years_at_current_address  zipcode  \
# count 12497.00              12497.00                  12497.00 12497.00
# mean      0.42                  0.38                      0.50     0.53
# std       0.19                  0.31                      0.30     0.29
# min       0.00                  0.00                      0.00     0.00
# 25%       0.29                  0.00                      0.23     0.33
# 50%       0.42                  0.40                      0.50     0.51
# 75%       0.54                  0.60                      0.77     0.76
# max       1.00                  1.00                      1.00     1.00
#
#        sanction_amount  processing_fee      gst  net_disbursement  \
# count         12497.00        12497.00 12497.00          12497.00
# mean              0.09            0.08     0.08              0.08
# std               0.12            0.11     0.11              0.11
# min              -0.00           -0.00    -0.00             -0.00
# 25%               0.02            0.02     0.02              0.02
# 50%               0.05            0.05     0.05              0.05
# 75%               0.10            0.09     0.09              0.09
# max               0.98            0.96     0.96              0.96
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count            12497.00               12497.00                     12497.00
# mean                 0.38                   0.26                         0.12
# std                  0.23                   0.25                         0.13
# min                  0.00                   0.00                         0.00
# 25%                  0.19                   0.08                         0.03
# 50%                  0.34                   0.20                         0.08
# 75%                  0.55                   0.36                         0.16
# max                  1.00                   1.00                         0.94
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count                 12497.00                   12497.00       12497.00
# mean                      0.50                       0.50           0.50
# std                       0.37                       0.41           0.25
# min                       0.00                       0.00           0.00
# 25%                       0.00                       0.00           0.38
# 50%                       0.33                       0.50           0.50
# 75%                       0.67                       1.00           0.62
# max                       1.00                       1.00           1.00
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# count                  12497.00        12497.00           12497.00
# mean                       0.44            0.29               0.11
# std                        0.30            0.23               0.17
# min                        0.00            0.00               0.00
# 25%                        0.18            0.11               0.00
# 50%                        0.39            0.20               0.04
# 75%                        0.68            0.50               0.13
# max                        1.00            1.00               1.00
#
#        avg_dpd_per_delinquency
# count                 12497.00
# mean                      0.33
# std                       0.29
# min                       0.00
# 25%                       0.00
# 50%                       0.44
# 75%                       0.58
# max                       1.00

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calculate_vif(data):
    vif_df=pd.DataFrame()
    vif_df['Column']=data.columns
    vif_df['VIF']=[variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return vif_df

# %%
calculate_vif(X_train[cols_to_scale])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                          Column    VIF
# 0                           age   5.70
# 1          number_of_dependants   2.73
# 2      years_at_current_address   3.42
# 3                       zipcode   3.80
# 4               sanction_amount 101.09
# 5                processing_fee    inf
# 6                           gst    inf
# 7              net_disbursement    inf
# 8            loan_tenure_months   6.18
# 9         principal_outstanding  16.33
# 10  bank_balance_at_application   9.34
# 11      number_of_open_accounts   4.39
# 12    number_of_closed_accounts   2.38
# 13                enquiry_count   6.41
# 14     credit_utilization_ratio   2.93
# 15               loan_to_income   6.96
# 16            delinquency_ratio   1.93
# 17      avg_dpd_per_delinquency   2.91

# %%
features_to_drop_vif=['sanction_amount','processing_fee','gst','net_disbursement','principal_outstanding']
X_train_1=X_train.drop(features_to_drop_vif,axis='columns')

# %%
numeric_columns=X_train_1.select_dtypes(['int64','float64']).columns
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
vif_df=calculate_vif(X_train_1[numeric_columns])
vif_df
# Out:
#                          Column  VIF
# 0                           age 5.43
# 1          number_of_dependants 2.73
# 2      years_at_current_address 3.40
# 3                       zipcode 3.78
# 4            loan_tenure_months 6.02
# 5   bank_balance_at_application 1.80
# 6       number_of_open_accounts 4.35
# 7     number_of_closed_accounts 2.37
# 8                 enquiry_count 6.38
# 9      credit_utilization_ratio 2.92
# 10               loan_to_income 4.56
# 11            delinquency_ratio 1.93
# 12      avg_dpd_per_delinquency 2.91

# %%
selected_numeric_features_vif=vif_df.Column.values
selected_numeric_features_vif
# Out:
# array(['age', 'number_of_dependants', 'years_at_current_address',
#        'zipcode', 'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts',
#        'enquiry_count', 'credit_utilization_ratio', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'], dtype=object)

# %%
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
plt.figure(figsize=(12,12))
cm=df_train_3[numeric_columns.append(pd.Index(['default']))].corr()
sns.heatmap(cm,annot=True,fmt='0.2f')
plt.xticks(rotation=45,ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Feature Selection: Catrgorical Features:

# %%
X_train_1.head()
# Out:
#        age gender marital_status employment_status  number_of_dependants  \
# 12746 0.79      M        Married     Self-Employed                  0.60
# 32495 0.50      F         Single          Salaried                  0.00
# 43675 0.38      M         Single          Salaried                  0.00
# 9040  0.46      M        Married          Salaried                  0.40
# 13077 0.77      M        Married     Self-Employed                  0.80
#
#       residence_type  years_at_current_address       city        state  \
# 12746          Owned                      0.97  Hyderabad    Telangana
# 32495          Owned                      0.87     Mumbai  Maharashtra
# 43675       Mortgage                      0.83    Chennai   Tamil Nadu
# 9040        Mortgage                      0.97  Bangalore    Karnataka
# 13077          Owned                      0.93       Pune  Maharashtra
#
#        zipcode  ...  loan_type loan_tenure_months  \
# 12746     0.66  ...    Secured               0.42
# 32495     0.49  ...    Secured               0.83
# 43675     0.83  ...    Secured               0.49
# 9040      0.76  ...    Secured               0.64
# 13077     0.51  ...  Unsecured               0.17
#
#        bank_balance_at_application  number_of_open_accounts  \
# 12746                         0.61                     1.00
# 32495                         0.03                     0.67
# 43675                         0.17                     0.00
# 9040                          0.08                     0.67
# 13077                         0.07                     0.00
#
#        number_of_closed_accounts  enquiry_count  credit_utilization_ratio  \
# 12746                       1.00           0.38                      0.36
# 32495                       0.50           0.50                      0.05
# 43675                       0.50           0.38                      0.00
# 9040                        0.00           0.88                      0.88
# 13077                       1.00           0.00                      0.72
#
#        loan_to_income  delinquency_ratio  avg_dpd_per_delinquency
# 12746            0.41               0.13                     0.59
# 32495            0.31               0.06                     0.62
# 43675            0.76               0.22                     0.56
# 9040             0.19               0.00                     0.00
# 13077            0.05               0.00                     0.00
#
# [5 rows x 21 columns]

# %%
# Calculate woe and iv:
def calculate_woe_iv(df,feature,target):
    grouped=df.groupby(feature)[target].agg(['count','sum'])
    grouped=grouped.rename(columns={'count':'total','sum':'good'})
    grouped['bad']=grouped['total']-grouped['good']
    
    total_good=grouped['good'].sum()
    total_bad=grouped['bad'].sum()
    
    grouped['good_pct']=grouped['good']/total_good
    grouped['bad_pct']=grouped['bad']/total_bad
    grouped['woe']=np.log(grouped['good_pct']/grouped['bad_pct'])
    grouped['iv']=(grouped['good_pct']-grouped['bad_pct'])*grouped['woe']
    
    grouped['woe']=grouped['woe'].replace([np.inf,-np.inf],0)
    grouped['iv']=grouped['iv'].replace([np.inf,-np.inf],0)
    
    total_iv=grouped['iv'].sum()
    
    return grouped,total_iv

grouped,total_iv=calculate_woe_iv(pd.concat([X_train_1,y_train],axis=1),'loan_purpose','default')
grouped
# Out:
#               total  good    bad  good_pct  bad_pct   woe   iv
# loan_purpose
# Auto           7447   327   7120      0.10     0.21 -0.72 0.08
# Education      5620   559   5061      0.17     0.15  0.16 0.00
# Home          11304  1734   9570      0.54     0.28  0.66 0.17
# Personal      13117   603  12514      0.19     0.37 -0.67 0.12

# %%
X_train_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37488 entries, 12746 to 37784
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          37488 non-null  float64
#  1   gender                       37488 non-null  object
#  2   marital_status               37488 non-null  object
#  3   employment_status            37488 non-null  object
#  4   number_of_dependants         37488 non-null  float64
#  5   residence_type               37488 non-null  object
#  6   years_at_current_address     37488 non-null  float64
#  7   city                         37488 non-null  object
#  8   state                        37488 non-null  object
#  9   zipcode                      37488 non-null  float64
#  10  loan_purpose                 37488 non-null  object
#  11  loan_type                    37488 non-null  object
#  12  loan_tenure_months           37488 non-null  float64
#  13  bank_balance_at_application  37488 non-null  float64
#  14  number_of_open_accounts      37488 non-null  float64
#  15  number_of_closed_accounts    37488 non-null  float64
#  16  enquiry_count                37488 non-null  float64
#  17  credit_utilization_ratio     37488 non-null  float64
#  18  loan_to_income               37488 non-null  float64
#  19  delinquency_ratio            37488 non-null  float64
#  20  avg_dpd_per_delinquency      37488 non-null  float64
# dtypes: float64(13), object(8)
# memory usage: 6.3+ MB

# %%
iv_values = {}
for feature in X_train_1.columns:
    if X_train_1[feature].dtype == 'object':
        _, iv = calculate_woe_iv(pd.concat([X_train_1, y_train],axis=1), feature, 'default' )
    else:
        X_binned = pd.cut(X_train_1[feature], bins=10, labels=False)
        _, iv = calculate_woe_iv(pd.concat([X_binned, y_train],axis=1), feature, 'default' )
    iv_values[feature] = iv
iv_values
# Out:
# {'age': np.float64(0.0890689462679479),
#  'gender': np.float64(0.00047449502170914947),
#  'marital_status': np.float64(0.001129766845390142),
#  'employment_status': np.float64(0.003953046301722585),
#  'number_of_dependants': np.float64(0.0019380899135053508),
#  'residence_type': np.float64(0.246745268718145),
#  'years_at_current_address': np.float64(0.0020800513608156363),
#  'city': np.float64(0.0019059578709781529),
#  'state': np.float64(0.0019005589806779287),
#  'zipcode': np.float64(0.0016677413243392572),
#  'loan_purpose': np.float64(0.3691197842282755),
#  'loan_type': np.float64(0.16319324904149224),
#  'loan_tenure_months': np.float64(0.21893515090196278),
#  'bank_balance_at_application': np.float64(0.0063187993277516365),
#  'number_of_open_accounts': np.float64(0.08463134083005877),
#  'number_of_closed_accounts': np.float64(0.0011964272592421567),
#  'enquiry_count': np.float64(0.007864214085342608),
#  'credit_utilization_ratio': np.float64(2.352965568168245),
#  'loan_to_income': np.float64(0.476415456948364),
#  'delinquency_ratio': np.float64(0.716576108689321),
#  'avg_dpd_per_delinquency': np.float64(0.40151905412190175)}

# %%
pd.set_option('display.float_format',lambda x: '{:.3f}'.format(x))
iv_df=pd.DataFrame(list(iv_values.items()), columns=['Feature', 'IV'])
iv_df=iv_df.sort_values(by='IV', ascending=False)
iv_df
# Out:
#                         Feature    IV
# 17     credit_utilization_ratio 2.353
# 19            delinquency_ratio 0.717
# 18               loan_to_income 0.476
# 20      avg_dpd_per_delinquency 0.402
# 10                 loan_purpose 0.369
# 5                residence_type 0.247
# 12           loan_tenure_months 0.219
# 11                    loan_type 0.163
# 0                           age 0.089
# 14      number_of_open_accounts 0.085
# 16                enquiry_count 0.008
# 13  bank_balance_at_application 0.006
# 3             employment_status 0.004
# 6      years_at_current_address 0.002
# 4          number_of_dependants 0.002
# 7                          city 0.002
# 8                         state 0.002
# 9                       zipcode 0.002
# 15    number_of_closed_accounts 0.001
# 2                marital_status 0.001
# 1                        gender 0.000

# %%
# selecting features that has IV > 0.02
selected_features_iv=[feature for feature,iv in iv_values.items() if iv > 0.02]
selected_features_iv
# Out:
# ['age',
#  'residence_type',
#  'loan_purpose',
#  'loan_type',
#  'loan_tenure_months',
#  'number_of_open_accounts',
#  'credit_utilization_ratio',
#  'loan_to_income',
#  'delinquency_ratio',
#  'avg_dpd_per_delinquency']

# %% [markdown]
# # Feature Encoding:

# %%
X_train_reduced=X_train_1[selected_features_iv]
X_test_reduced=X_test[selected_features_iv]

# %%
X_train_encoded=pd.get_dummies(X_train_reduced,drop_first=True)
X_train_encoded.head(3)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 12746 0.788               0.415                    1.000
# 32495 0.500               0.830                    0.667
# 43675 0.385               0.491                    0.000
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 12746                     0.364           0.415              0.132
# 32495                     0.051           0.307              0.062
# 43675                     0.000           0.759              0.222
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 12746                    0.590                  True                  False
# 32495                    0.620                  True                  False
# 43675                    0.560                 False                  False
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 12746                   False               True                  False
# 32495                    True              False                  False
# 43675                   False               True                  False
#
#        loan_type_Unsecured
# 12746                False
# 32495                False
# 43675                False

# %%
X_test_encoded=pd.get_dummies(X_test_reduced,drop_first=True)
X_test_encoded.head(3)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 19205 0.346               0.755                    0.333
# 15514 0.481               0.226                    1.000
# 30367 0.231               0.547                    0.667
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 19205                     0.990           0.550              0.000
# 15514                     0.323           0.220              0.000
# 30367                     0.828           0.180              0.000
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 19205                    0.000                  True                  False
# 15514                    0.000                  True                  False
# 30367                    0.000                  True                  False
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 19205                   False               True                  False
# 15514                    True              False                  False
# 30367                   False              False                  False
#
#        loan_type_Unsecured
# 19205                False
# 15514                False
# 30367                False

# %% [markdown]
# # Model Training:

# %% [markdown]
# ### Attempt 1
#
# 1. Logistic Regression, RandomForest & XGB
# 1. No handling of class imbalance

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

model=LogisticRegression()
model.fit(X_train_encoded,y_train)

y_pred=model.predict(X_test_encoded)
report=classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.85      0.72      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.91      0.85      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %%
feature_importance=model.coef_[0]
# Create a DataFrame for easier handling
coef_df=pd.DataFrame(feature_importance,index=X_train_encoded.columns,columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df=coef_df.sort_values(by='Coefficients',ascending=True)

# Plotting
plt.figure(figsize=(8,4))
plt.barh(coef_df.index, coef_df['Coefficients'],color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Logistic Regression')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

model=RandomForestClassifier()
model.fit(X_train_encoded,y_train)

y_pred=model.predict(X_test_encoded)
report=classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11423
#            1       0.85      0.71      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.91      0.85      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %%
from xgboost import XGBClassifier

model = XGBClassifier()
model.fit(X_train_encoded,y_train)

y_pred=model.predict(X_test_encoded)
report=classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     11423
#            1       0.82      0.76      0.79      1074
#
#     accuracy                           0.97     12497
#    macro avg       0.90      0.87      0.89     12497
# weighted avg       0.96      0.97      0.96     12497

# %%
#RandomizedSearch CV for attempt 1: Logistic Regression:
from sklearn.model_selection import RandomizedSearchCV
param_dist={
    'C':np.logspace(-4, 4, 20),  # Logarithmically spaced values from 10^-4 to 10^4
    'solver':['lbfgs','saga','liblinear','newton-cg']   # Algorithm to use in the optimization problem
}
# Create the Logistic Regression model
log_reg=LogisticRegression(max_iter=10000)  # Increased max_iter for convergence

# Set up RandomizedSearchCV
random_search=RandomizedSearchCV(
    estimator=log_reg,
    param_distributions=param_dist,
    n_iter=50,  # Number of parameter settings that are sampled
    scoring='f1',
    cv=3,  # 5-fold cross-validation
    verbose=2,
    random_state=42,  # Set a random state for reproducibility
    n_jobs=-1  # Use all available cores
)

# Fit the RandomizedSearchCV to the training data
random_search.fit(X_train_encoded,y_train)
# Print the best parameters and best score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

best_model=random_search.best_estimator_
y_pred=best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test,y_pred))
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# Best Parameters: {'solver': 'liblinear', 'C': np.float64(1438.44988828766)}
# Best Score: 0.7578820896729832
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     11423
#            1       0.83      0.74      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.90      0.86      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %%
#RandomizedSearch CV for attempt 1: XGBoost:
from scipy.stats import uniform, randint
from sklearn.model_selection import RandomizedSearchCV
# Define parameter distribution for RandomizedSearchCV
param_dist={
    'n_estimators': [100, 150, 200, 250, 300],
    'max_depth': [3, 4, 5, 6, 7, 8, 9, 10],
    'learning_rate': [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3],
    'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'scale_pos_weight': [1, 2, 3, 5, 7, 10],
    'reg_alpha': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0],  # L1 regularization term
    'reg_lambda': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0]  # L2 regularization term
}
xgb=XGBClassifier()
random_search=RandomizedSearchCV(estimator=xgb,param_distributions=param_dist,n_iter=100,
                                   scoring='f1',cv=3,verbose=1,n_jobs=-1,random_state=42)
random_search.fit(X_train_encoded,y_train)

# Print the best parameters and best score
print(f"Best Parameters:{random_search.best_params_}")
print(f"Best Score:{random_search.best_score_}")

best_model=random_search.best_estimator_
y_pred=best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test,y_pred))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Best Parameters:{'subsample': 0.8, 'scale_pos_weight': 2, 'reg_lambda': 1.0, 'reg_alpha': 5.0, 'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.2, 'colsample_bytree': 0.9}
# Best Score:0.7883672970285227
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     11423
#            1       0.77      0.83      0.80      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.88      0.91      0.89     12497
# weighted avg       0.97      0.96      0.96     12497

# %% [markdown]
# ### Attempt 2
#
# 1. Logistic Regression & XGB
# 1. Handle Class Imbalance Using Under Sampling

# %%
from imblearn.under_sampling import RandomUnderSampler

rus=RandomUnderSampler(random_state=42)
X_train_res,y_train_res=rus.fit_resample(X_train_encoded,y_train)
y_train_res.value_counts()
# Out:
# default
# 0    3223
# 1    3223
# Name: count, dtype: int64

# %%
model=LogisticRegression()
model.fit(X_train_res,y_train_res)

y_pred=model.predict(X_test_encoded)
report=classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     11423
#            1       0.51      0.96      0.67      1074
#
#     accuracy                           0.92     12497
#    macro avg       0.75      0.93      0.81     12497
# weighted avg       0.95      0.92      0.93     12497

# %%
model=XGBClassifier(**random_search.best_params_)
model.fit(X_train_res,y_train_res)

y_pred=model.predict(X_test_encoded)
report=classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     11423
#            1       0.51      0.99      0.67      1074
#
#     accuracy                           0.92     12497
#    macro avg       0.75      0.95      0.81     12497
# weighted avg       0.96      0.92      0.93     12497

# %% [markdown]
# ### Attempt 3
#
# 1. Logistic Regression
# 1. Handle Class Imbalance Using SMOTE Tomek
# 1. Parameter tunning using optuna

# %%
from imblearn.combine import SMOTETomek

smt=SMOTETomek(random_state=42)
X_train_smt,y_train_smt=smt.fit_resample(X_train_encoded,y_train)
y_train_smt.value_counts()
# Out:
# default
# 0    34195
# 1    34195
# Name: count, dtype: int64

# %%
model=LogisticRegression()
model.fit(X_train_smt,y_train_smt)

y_pred=model.predict(X_test_encoded)
report=classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.55      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.77      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %%
import optuna
from sklearn.metrics import make_scorer,f1_score
from sklearn.model_selection import cross_val_score

# %%
# Define the objective function for Optuna
def objective(trial):
    param={
        'C': trial.suggest_float('C',1e-4,1e4,log=True),  # Logarithmically spaced values
        'solver': trial.suggest_categorical('solver',['lbfgs','liblinear','saga','newton-cg']),  # Solvers
        'tol': trial.suggest_float('tol',1e-6,1e-1,log=True),  # Logarithmically spaced values for tolerance
        'class_weight': trial.suggest_categorical('class_weight',[None,'balanced'])  # Class weights
    }

    model=LogisticRegression(**param,max_iter=10000)
    
    # Calculate the cross-validated f1_score
    f1_scorer=make_scorer(f1_score, average='macro')
    scores=cross_val_score(model,X_train_smt,y_train_smt,cv=3,scoring=f1_scorer,n_jobs=-1)
    
    return np.mean(scores)

study_logistic=optuna.create_study(direction='maximize')
study_logistic.optimize(objective, n_trials=50)
# Out:
# [I 2026-06-29 09:58:51,482] A new study created in memory with name: no-name-c5f50f92-6dd6-439c-9a4e-23e304ec7d3f
# [I 2026-06-29 09:58:52,190] Trial 0 finished with value: 0.9406645688827435 and parameters: {'C': 0.14179186672533922, 'solver': 'liblinear', 'tol': 1.0675690996923224e-06, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.9406645688827435.
# [I 2026-06-29 09:58:52,469] Trial 1 finished with value: 0.9160836019322062 and parameters: {'C': 0.12057275883061037, 'solver': 'lbfgs', 'tol': 0.012277133180287393, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.9406645688827435.
# [I 2026-06-29 09:58:53,266] Trial 2 finished with value: 0.9456794085990863 and parameters: {'C': 1462.2283629367018, 'solver': 'liblinear', 'tol': 2.2083255194754832e-05, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:58:53,902] Trial 3 finished with value: 0.9456208359010468 and parameters: {'C': 41.14871133534009, 'solver': 'lbfgs', 'tol': 3.1361576878376924e-06, 'class_weight': None}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:58:54,508] Trial 4 finished with value: 0.936402525289696 and parameters: {'C': 0.06150395119056882, 'solver': 'liblinear', 'tol': 3.719888038725319e-05, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:58:55,134] Trial 5 finished with value: 0.9456354872629106 and parameters: {'C': 43.000626047216194, 'solver': 'lbfgs', 'tol': 3.650382274425887e-06, 'class_weight': None}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:58:55,480] Trial 6 finished with value: 0.9080195651133378 and parameters: {'C': 8432.372060633648, 'solver': 'newton-cg', 'tol': 0.023922484524124432, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:58:56,159] Trial 7 finished with value: 0.9416197224190435 and parameters: {'C': 0.18499782361672426, 'solver': 'liblinear', 'tol': 9.510295974041286e-06, 'class_weight': None}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:58:56,628] Trial 8 finished with value: 0.8432644836895528 and parameters: {'C': 0.00019887939582423475, 'solver': 'saga', 'tol': 0.019777929818306436, 'class_weight': None}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:58:57,226] Trial 9 finished with value: 0.9456640030071095 and parameters: {'C': 31.964483956544232, 'solver': 'liblinear', 'tol': 0.005465402387073284, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:58:57,975] Trial 10 finished with value: 0.9456793608932644 and parameters: {'C': 6911.39177451056, 'solver': 'saga', 'tol': 0.0004330436285528902, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:58:58,664] Trial 11 finished with value: 0.9456648002472416 and parameters: {'C': 7230.682876685086, 'solver': 'saga', 'tol': 0.0004299840325903626, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:58:59,412] Trial 12 finished with value: 0.9456503142626028 and parameters: {'C': 637.4085216207893, 'solver': 'saga', 'tol': 0.0002224637939435962, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:59:00,045] Trial 13 finished with value: 0.9456192785931149 and parameters: {'C': 406.7607626260638, 'solver': 'newton-cg', 'tol': 0.0006136471388931797, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:59:00,827] Trial 14 finished with value: 0.9456794085990863 and parameters: {'C': 742.591021071675, 'solver': 'saga', 'tol': 7.236320988055938e-05, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:59:01,521] Trial 15 finished with value: 0.9456613504204835 and parameters: {'C': 2.37480788527364, 'solver': 'liblinear', 'tol': 5.569109304612035e-05, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:59:02,447] Trial 16 finished with value: 0.9456648044554358 and parameters: {'C': 423.8362966418009, 'solver': 'saga', 'tol': 3.974686077502493e-05, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:59:03,056] Trial 17 finished with value: 0.9451730785990528 and parameters: {'C': 4.684352876448426, 'solver': 'newton-cg', 'tol': 0.001953840847064958, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:59:03,855] Trial 18 finished with value: 0.9197757401463562 and parameters: {'C': 0.003203886678643302, 'solver': 'saga', 'tol': 0.00011936854741573995, 'class_weight': None}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:59:04,617] Trial 19 finished with value: 0.9456794085990863 and parameters: {'C': 935.2709568355907, 'solver': 'liblinear', 'tol': 1.4393842775944939e-05, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:59:04,932] Trial 20 finished with value: 0.944160696871689 and parameters: {'C': 8.304938985527585, 'solver': 'saga', 'tol': 0.08351801896504477, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:59:05,708] Trial 21 finished with value: 0.9456794085990863 and parameters: {'C': 689.5573451690584, 'solver': 'liblinear', 'tol': 1.7196741576075123e-05, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:59:06,473] Trial 22 finished with value: 0.9456794085990863 and parameters: {'C': 1549.4810592618378, 'solver': 'liblinear', 'tol': 9.884821323780134e-06, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:59:07,153] Trial 23 finished with value: 0.9456207881200721 and parameters: {'C': 96.36312845544686, 'solver': 'liblinear', 'tol': 9.192815963529728e-05, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:59:07,977] Trial 24 finished with value: 0.9456500987009903 and parameters: {'C': 141.14254916695512, 'solver': 'liblinear', 'tol': 4.274177393253364e-06, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:59:08,765] Trial 25 finished with value: 0.9456794085990863 and parameters: {'C': 1684.7300680638937, 'solver': 'liblinear', 'tol': 1.98128366890849e-05, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:59:09,174] Trial 26 finished with value: 0.945576033143646 and parameters: {'C': 2157.1954976762363, 'solver': 'lbfgs', 'tol': 0.0013249346301904524, 'class_weight': None}. Best is trial 2 with value: 0.9456794085990863.
# [I 2026-06-29 09:59:09,996] Trial 27 finished with value: 0.9456935841891859 and parameters: {'C': 11.585216507442485, 'solver': 'newton-cg', 'tol': 1.2783131776594286e-06, 'class_weight': 'balanced'}. Best is trial 27 with value: 0.9456935841891859.
# [I 2026-06-29 09:59:10,811] Trial 28 finished with value: 0.9454993977980357 and parameters: {'C': 0.918067331044681, 'solver': 'newton-cg', 'tol': 1.247246404664121e-06, 'class_weight': 'balanced'}. Best is trial 27 with value: 0.9456935841891859.
# [I 2026-06-29 09:59:11,646] Trial 29 finished with value: 0.9457081808035305 and parameters: {'C': 10.659871052947087, 'solver': 'newton-cg', 'tol': 1.4902647197209455e-06, 'class_weight': 'balanced'}. Best is trial 29 with value: 0.9457081808035305.
# [I 2026-06-29 09:59:12,486] Trial 30 finished with value: 0.9450733940391863 and parameters: {'C': 0.5190073254260618, 'solver': 'newton-cg', 'tol': 1.660377014567971e-06, 'class_weight': 'balanced'}. Best is trial 29 with value: 0.9457081808035305.
# [I 2026-06-29 09:59:13,444] Trial 31 finished with value: 0.9457081210202624 and parameters: {'C': 9.649914914532623, 'solver': 'newton-cg', 'tol': 5.542289117294063e-06, 'class_weight': 'balanced'}. Best is trial 29 with value: 0.9457081808035305.
# [I 2026-06-29 09:59:14,540] Trial 32 finished with value: 0.9457081808035305 and parameters: {'C': 10.867146494458856, 'solver': 'newton-cg', 'tol': 2.191821948102562e-06, 'class_weight': 'balanced'}. Best is trial 29 with value: 0.9457081808035305.
# [I 2026-06-29 09:59:15,487] Trial 33 finished with value: 0.9456497363170233 and parameters: {'C': 13.09041183424914, 'solver': 'newton-cg', 'tol': 1.0668257521281179e-06, 'class_weight': 'balanced'}. Best is trial 29 with value: 0.9457081808035305.
# [I 2026-06-29 09:59:16,394] Trial 34 finished with value: 0.9457947369713161 and parameters: {'C': 2.926791266693087, 'solver': 'newton-cg', 'tol': 2.2350792000480504e-06, 'class_weight': 'balanced'}. Best is trial 34 with value: 0.9457947369713161.
# [I 2026-06-29 09:59:17,183] Trial 35 finished with value: 0.9457945170632396 and parameters: {'C': 2.6497803129077035, 'solver': 'newton-cg', 'tol': 6.313908700484956e-06, 'class_weight': 'balanced'}. Best is trial 34 with value: 0.9457947369713161.
# [I 2026-06-29 09:59:17,854] Trial 36 finished with value: 0.9344926228587004 and parameters: {'C': 0.020068888604898864, 'solver': 'newton-cg', 'tol': 2.6421683900342864e-06, 'class_weight': 'balanced'}. Best is trial 34 with value: 0.9457947369713161.
# [I 2026-06-29 09:59:18,747] Trial 37 finished with value: 0.9457943855264447 and parameters: {'C': 2.5488360077167656, 'solver': 'newton-cg', 'tol': 6.184185130814713e-06, 'class_weight': None}. Best is trial 34 with value: 0.9457947369713161.
# [I 2026-06-29 09:59:19,531] Trial 38 finished with value: 0.9457934998608476 and parameters: {'C': 1.7364377659349568, 'solver': 'newton-cg', 'tol': 6.6273669508557015e-06, 'class_weight': None}. Best is trial 34 with value: 0.9457947369713161.
# [I 2026-06-29 09:59:20,299] Trial 39 finished with value: 0.9430619112043034 and parameters: {'C': 0.1894579717187347, 'solver': 'newton-cg', 'tol': 6.317703415843709e-06, 'class_weight': None}. Best is trial 34 with value: 0.9457947369713161.
# [I 2026-06-29 09:59:21,057] Trial 40 finished with value: 0.9457644771179935 and parameters: {'C': 2.0388152701719147, 'solver': 'newton-cg', 'tol': 3.0197007122913525e-05, 'class_weight': None}. Best is trial 34 with value: 0.9457947369713161.
# [I 2026-06-29 09:59:21,828] Trial 41 finished with value: 0.9457651366605896 and parameters: {'C': 2.5832210790715866, 'solver': 'newton-cg', 'tol': 8.129447590468328e-06, 'class_weight': None}. Best is trial 34 with value: 0.9457947369713161.
# [I 2026-06-29 09:59:22,573] Trial 42 finished with value: 0.9448383423162298 and parameters: {'C': 0.424418750456504, 'solver': 'newton-cg', 'tol': 8.303382180744591e-06, 'class_weight': None}. Best is trial 34 with value: 0.9457947369713161.
# [I 2026-06-29 09:59:23,080] Trial 43 finished with value: 0.9380503304900122 and parameters: {'C': 0.04484458582731025, 'solver': 'lbfgs', 'tol': 4.148599788193207e-06, 'class_weight': None}. Best is trial 34 with value: 0.9457947369713161.
# [I 2026-06-29 09:59:23,834] Trial 44 finished with value: 0.9457934998608476 and parameters: {'C': 1.7205251136018238, 'solver': 'newton-cg', 'tol': 1.2419773328661843e-05, 'class_weight': None}. Best is trial 34 with value: 0.9457947369713161.
# [I 2026-06-29 09:59:24,590] Trial 45 finished with value: 0.9453964851016933 and parameters: {'C': 0.7126934196290421, 'solver': 'newton-cg', 'tol': 2.6692584134539646e-06, 'class_weight': None}. Best is trial 34 with value: 0.9457947369713161.
# [I 2026-06-29 09:59:25,322] Trial 46 finished with value: 0.9455768188300726 and parameters: {'C': 30.402331363474303, 'solver': 'newton-cg', 'tol': 3.1746980562195545e-05, 'class_weight': None}. Best is trial 34 with value: 0.9457947369713161.
# [I 2026-06-29 09:59:26,071] Trial 47 finished with value: 0.9440899045847213 and parameters: {'C': 0.30451163923062113, 'solver': 'newton-cg', 'tol': 1.2360819790127577e-05, 'class_weight': None}. Best is trial 34 with value: 0.9457947369713161.
# [I 2026-06-29 09:59:26,615] Trial 48 finished with value: 0.9409023646989662 and parameters: {'C': 0.0920180155602414, 'solver': 'lbfgs', 'tol': 3.7430207257725378e-06, 'class_weight': None}. Best is trial 34 with value: 0.9457947369713161.
# [I 2026-06-29 09:59:27,287] Trial 49 finished with value: 0.9456317959968047 and parameters: {'C': 2.0083621182674145, 'solver': 'newton-cg', 'tol': 0.00015047546896267358, 'class_weight': None}. Best is trial 34 with value: 0.9457947369713161.

# %%
print('Best trial:')
trial=study_logistic.best_trial
print('F1-score: {}'.format(trial.value))
print('Params: ')
for key,value in trial.params.items():
    print('  {}: {}'.format(key, value))
    
best_model_logistic=LogisticRegression(**study_logistic.best_params)
best_model_logistic.fit(X_train_smt,y_train_smt)

# Evaluate on the test set
y_pred=best_model_logistic.predict(X_test_encoded)

report=classification_report(y_test,y_pred)
print(report)
# Out:
# Best trial:
# F1-score: 0.9457947369713161
# Params:
#   C: 2.926791266693087
#   solver: newton-cg
#   tol: 2.2350792000480504e-06
#   class_weight: balanced
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.56      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.77      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %% [markdown]
# ### Attempt 4
#
# 1. XGBoost
# 1. Handle Class Imbalance Using SMOTE Tomek
# 1. Parameter tunning using optuna

# %%
# Define the objective function for Optuna
def objective(trial):
    param = {
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'verbosity': 0,
        'booster': 'gbtree',
        'lambda': trial.suggest_float('lambda', 1e-3, 10.0, log=True),
        'alpha': trial.suggest_float('alpha', 1e-3, 10.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.4, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'eta': trial.suggest_float('eta', 0.01, 0.3),
        'gamma': trial.suggest_float('gamma', 0, 10),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'max_delta_step': trial.suggest_int('max_delta_step', 0, 10)
    }

    model=XGBClassifier(**param)
    
    # Calculate the cross-validated f1_score
    f1_scorer=make_scorer(f1_score, average='macro')
    scores=cross_val_score(model,X_train_smt,y_train_smt,cv=3,scoring=f1_scorer,n_jobs=-1)
    
    return np.mean(scores)

study_xgb=optuna.create_study(direction='maximize')
study_xgb.optimize(objective,n_trials=50)
# Out:
# [I 2026-06-29 09:59:28,252] A new study created in memory with name: no-name-82041fed-e704-4d4d-859b-cd1a19ff2f03
# [I 2026-06-29 09:59:30,273] Trial 0 finished with value: 0.9624026675561971 and parameters: {'lambda': 0.45934891124708715, 'alpha': 0.0015255001013035616, 'subsample': 0.6493021269004993, 'colsample_bytree': 0.9776705159517723, 'max_depth': 6, 'eta': 0.15929857351484872, 'gamma': 4.367840373731887, 'scale_pos_weight': 8.872576532823057, 'min_child_weight': 3, 'max_delta_step': 1}. Best is trial 0 with value: 0.9624026675561971.
# [I 2026-06-29 09:59:32,738] Trial 1 finished with value: 0.9676422931024641 and parameters: {'lambda': 0.048478747790914746, 'alpha': 0.03369903846036335, 'subsample': 0.6233629902438798, 'colsample_bytree': 0.9732234777683831, 'max_depth': 10, 'eta': 0.12104787313709174, 'gamma': 4.634112475171664, 'scale_pos_weight': 6.820708286950891, 'min_child_weight': 10, 'max_delta_step': 4}. Best is trial 1 with value: 0.9676422931024641.
# [I 2026-06-29 09:59:34,357] Trial 2 finished with value: 0.9579597901371821 and parameters: {'lambda': 1.507815370682077, 'alpha': 1.3602883207946441, 'subsample': 0.8784407304569097, 'colsample_bytree': 0.8217594689912691, 'max_depth': 3, 'eta': 0.2875527687911705, 'gamma': 9.591354135355406, 'scale_pos_weight': 3.535536128979819, 'min_child_weight': 4, 'max_delta_step': 8}. Best is trial 1 with value: 0.9676422931024641.
# [I 2026-06-29 09:59:36,280] Trial 3 finished with value: 0.9571283616489503 and parameters: {'lambda': 7.5168186170466, 'alpha': 0.1655057219422192, 'subsample': 0.5701581143379574, 'colsample_bytree': 0.6579618722455018, 'max_depth': 6, 'eta': 0.19326925824817015, 'gamma': 7.97858103647809, 'scale_pos_weight': 8.258457041190578, 'min_child_weight': 8, 'max_delta_step': 9}. Best is trial 1 with value: 0.9676422931024641.
# [I 2026-06-29 09:59:37,797] Trial 4 finished with value: 0.9432915311555264 and parameters: {'lambda': 0.0011211162135325136, 'alpha': 0.11136437855205361, 'subsample': 0.4800999945012405, 'colsample_bytree': 0.4431039781617417, 'max_depth': 3, 'eta': 0.10503006404002967, 'gamma': 0.22058848200083303, 'scale_pos_weight': 2.459559485098871, 'min_child_weight': 4, 'max_delta_step': 9}. Best is trial 1 with value: 0.9676422931024641.
# [I 2026-06-29 09:59:39,682] Trial 5 finished with value: 0.9622170575605044 and parameters: {'lambda': 0.0015173391882334273, 'alpha': 0.002398636595874292, 'subsample': 0.5741593522698415, 'colsample_bytree': 0.4070305696377244, 'max_depth': 8, 'eta': 0.2163645912297964, 'gamma': 6.801297611296602, 'scale_pos_weight': 7.088440628972533, 'min_child_weight': 1, 'max_delta_step': 7}. Best is trial 1 with value: 0.9676422931024641.
# [I 2026-06-29 09:59:41,785] Trial 6 finished with value: 0.9620387563526536 and parameters: {'lambda': 0.0017552808020500372, 'alpha': 4.267686665296567, 'subsample': 0.9820082684250901, 'colsample_bytree': 0.4309219516477021, 'max_depth': 9, 'eta': 0.21645885390341973, 'gamma': 4.472201473521869, 'scale_pos_weight': 8.1095967040874, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 1 with value: 0.9676422931024641.
# [I 2026-06-29 09:59:43,719] Trial 7 finished with value: 0.9557043400804082 and parameters: {'lambda': 0.0028332452794515546, 'alpha': 0.010724836669293357, 'subsample': 0.831077938519792, 'colsample_bytree': 0.4551478834508448, 'max_depth': 5, 'eta': 0.2152883494647238, 'gamma': 6.765906192034475, 'scale_pos_weight': 6.397659336115868, 'min_child_weight': 10, 'max_delta_step': 4}. Best is trial 1 with value: 0.9676422931024641.
# [I 2026-06-29 09:59:45,457] Trial 8 finished with value: 0.9685433731197882 and parameters: {'lambda': 0.001096734093641777, 'alpha': 1.0527232584515536, 'subsample': 0.5133422735847605, 'colsample_bytree': 0.924973070872036, 'max_depth': 5, 'eta': 0.25945956992033115, 'gamma': 4.863189790914934, 'scale_pos_weight': 2.645759782056416, 'min_child_weight': 9, 'max_delta_step': 8}. Best is trial 8 with value: 0.9685433731197882.
# [I 2026-06-29 09:59:47,530] Trial 9 finished with value: 0.9612594837634415 and parameters: {'lambda': 2.120211682281942, 'alpha': 0.001381308139845253, 'subsample': 0.8830817618813868, 'colsample_bytree': 0.7519914947296362, 'max_depth': 6, 'eta': 0.14098822007084227, 'gamma': 8.340752169602492, 'scale_pos_weight': 4.972741261430303, 'min_child_weight': 4, 'max_delta_step': 10}. Best is trial 8 with value: 0.9685433731197882.
# [I 2026-06-29 09:59:49,493] Trial 10 finished with value: 0.9401949269787452 and parameters: {'lambda': 0.026547305856414828, 'alpha': 0.8339821456391887, 'subsample': 0.40274447481778897, 'colsample_bytree': 0.8588523131867248, 'max_depth': 4, 'eta': 0.021450972778530614, 'gamma': 1.7341720692006843, 'scale_pos_weight': 1.1194004949878216, 'min_child_weight': 7, 'max_delta_step': 6}. Best is trial 8 with value: 0.9685433731197882.
# [I 2026-06-29 09:59:51,546] Trial 11 finished with value: 0.9716636865213885 and parameters: {'lambda': 0.026754473545126264, 'alpha': 0.02112867728413116, 'subsample': 0.6973386023218435, 'colsample_bytree': 0.9909250893366284, 'max_depth': 8, 'eta': 0.29824273622665576, 'gamma': 2.8835068518118145, 'scale_pos_weight': 4.671876420229321, 'min_child_weight': 10, 'max_delta_step': 4}. Best is trial 11 with value: 0.9716636865213885.
# [I 2026-06-29 09:59:53,610] Trial 12 finished with value: 0.9723665512815489 and parameters: {'lambda': 0.010130659273649433, 'alpha': 0.48213223543243194, 'subsample': 0.7524641930602968, 'colsample_bytree': 0.8769581749294015, 'max_depth': 8, 'eta': 0.2997047422962039, 'gamma': 2.564490105196142, 'scale_pos_weight': 4.607375806380679, 'min_child_weight': 8, 'max_delta_step': 3}. Best is trial 12 with value: 0.9723665512815489.
# [I 2026-06-29 09:59:55,603] Trial 13 finished with value: 0.9720145990670336 and parameters: {'lambda': 0.011786855059115713, 'alpha': 0.0204520665058444, 'subsample': 0.777839187289576, 'colsample_bytree': 0.6512360244809196, 'max_depth': 8, 'eta': 0.28454135317037166, 'gamma': 2.60060748617194, 'scale_pos_weight': 4.538811192497914, 'min_child_weight': 7, 'max_delta_step': 2}. Best is trial 12 with value: 0.9723665512815489.
# [I 2026-06-29 09:59:57,602] Trial 14 finished with value: 0.9725275266063839 and parameters: {'lambda': 0.00816463496992815, 'alpha': 0.27597684144832724, 'subsample': 0.7798295314307981, 'colsample_bytree': 0.6192833684068285, 'max_depth': 8, 'eta': 0.2643406379000131, 'gamma': 2.4762237400014775, 'scale_pos_weight': 3.9435349573061758, 'min_child_weight': 6, 'max_delta_step': 2}. Best is trial 14 with value: 0.9725275266063839.
# [I 2026-06-29 10:00:00,495] Trial 15 finished with value: 0.9754280748854814 and parameters: {'lambda': 0.00514147957331731, 'alpha': 0.30225428198426224, 'subsample': 0.7557756814527795, 'colsample_bytree': 0.5395342694520642, 'max_depth': 10, 'eta': 0.25253987758080165, 'gamma': 0.302397266857521, 'scale_pos_weight': 3.720892671252414, 'min_child_weight': 6, 'max_delta_step': 2}. Best is trial 15 with value: 0.9754280748854814.
# [I 2026-06-29 10:00:02,744] Trial 16 finished with value: 0.9702853087688093 and parameters: {'lambda': 0.14572231409358313, 'alpha': 9.041099873783415, 'subsample': 0.7458822307054723, 'colsample_bytree': 0.5469178844703528, 'max_depth': 10, 'eta': 0.25261334184102824, 'gamma': 0.4056115714714905, 'scale_pos_weight': 3.048804760225246, 'min_child_weight': 6, 'max_delta_step': 0}. Best is trial 15 with value: 0.9754280748854814.
# [I 2026-06-29 10:00:04,830] Trial 17 finished with value: 0.9751378612726831 and parameters: {'lambda': 0.005615671156697644, 'alpha': 0.4604779140289399, 'subsample': 0.9902095869107177, 'colsample_bytree': 0.5505441200880954, 'max_depth': 9, 'eta': 0.2500624247892143, 'gamma': 1.2722823381227282, 'scale_pos_weight': 1.0895015701574886, 'min_child_weight': 6, 'max_delta_step': 2}. Best is trial 15 with value: 0.9754280748854814.
# [I 2026-06-29 10:00:07,952] Trial 18 finished with value: 0.9688355710278417 and parameters: {'lambda': 0.004742049338965611, 'alpha': 2.2803513780675218, 'subsample': 0.9816634701893716, 'colsample_bytree': 0.5401403839521899, 'max_depth': 9, 'eta': 0.06333340761042767, 'gamma': 1.1502664439762382, 'scale_pos_weight': 1.4900951848801636, 'min_child_weight': 5, 'max_delta_step': 2}. Best is trial 15 with value: 0.9754280748854814.
# [I 2026-06-29 10:00:10,587] Trial 19 finished with value: 0.9752392783354855 and parameters: {'lambda': 0.15504783255637766, 'alpha': 0.05693308001683483, 'subsample': 0.9381762779939351, 'colsample_bytree': 0.535115690782183, 'max_depth': 10, 'eta': 0.19021961081874894, 'gamma': 1.2722829779116482, 'scale_pos_weight': 1.950845624947549, 'min_child_weight': 1, 'max_delta_step': 5}. Best is trial 15 with value: 0.9754280748854814.
# [I 2026-06-29 10:00:12,548] Trial 20 finished with value: 0.971313563466774 and parameters: {'lambda': 0.17414473662068558, 'alpha': 0.005824640749322338, 'subsample': 0.8828901322233236, 'colsample_bytree': 0.7251590295689033, 'max_depth': 10, 'eta': 0.18209807017396484, 'gamma': 5.914108961257451, 'scale_pos_weight': 2.080586814367761, 'min_child_weight': 1, 'max_delta_step': 6}. Best is trial 15 with value: 0.9754280748854814.
# [I 2026-06-29 10:00:14,783] Trial 21 finished with value: 0.9748732868377626 and parameters: {'lambda': 0.3906621222114883, 'alpha': 0.06749190869975008, 'subsample': 0.9471195989805432, 'colsample_bytree': 0.5473003189567489, 'max_depth': 9, 'eta': 0.23107663830809455, 'gamma': 1.313077038338875, 'scale_pos_weight': 1.7281080243585545, 'min_child_weight': 5, 'max_delta_step': 5}. Best is trial 15 with value: 0.9754280748854814.
# [I 2026-06-29 10:00:16,890] Trial 22 finished with value: 0.9732800052052752 and parameters: {'lambda': 0.058421633250184436, 'alpha': 0.3223809615876413, 'subsample': 0.9285933764776527, 'colsample_bytree': 0.4958526518235302, 'max_depth': 10, 'eta': 0.18528879089344957, 'gamma': 3.4195171573398917, 'scale_pos_weight': 1.0001398892733748, 'min_child_weight': 2, 'max_delta_step': 1}. Best is trial 15 with value: 0.9754280748854814.
# [I 2026-06-29 10:00:19,612] Trial 23 finished with value: 0.9743597740832618 and parameters: {'lambda': 0.022303499822182205, 'alpha': 0.06191450739282559, 'subsample': 0.831333542776949, 'colsample_bytree': 0.5968724921901639, 'max_depth': 9, 'eta': 0.2373487784928773, 'gamma': 0.006235658825085422, 'scale_pos_weight': 3.549321944987299, 'min_child_weight': 7, 'max_delta_step': 3}. Best is trial 15 with value: 0.9754280748854814.
# [I 2026-06-29 10:00:21,753] Trial 24 finished with value: 0.9723527759579462 and parameters: {'lambda': 0.004205832366531959, 'alpha': 0.204383691176241, 'subsample': 0.941317927673583, 'colsample_bytree': 0.498378755461441, 'max_depth': 7, 'eta': 0.1661279629856072, 'gamma': 1.5521045842065802, 'scale_pos_weight': 2.207297028867359, 'min_child_weight': 6, 'max_delta_step': 3}. Best is trial 15 with value: 0.9754280748854814.
# [I 2026-06-29 10:00:23,923] Trial 25 finished with value: 0.9699177289220601 and parameters: {'lambda': 0.08098071725015597, 'alpha': 0.5325125383031185, 'subsample': 0.9845568011331878, 'colsample_bytree': 0.582239114005719, 'max_depth': 10, 'eta': 0.2006667062653872, 'gamma': 3.605128353555532, 'scale_pos_weight': 5.643490535001339, 'min_child_weight': 5, 'max_delta_step': 5}. Best is trial 15 with value: 0.9754280748854814.
# [I 2026-06-29 10:00:26,487] Trial 26 finished with value: 0.9711483034556952 and parameters: {'lambda': 0.323586482682943, 'alpha': 0.05326996919044503, 'subsample': 0.8405703455614802, 'colsample_bytree': 0.4992106568688029, 'max_depth': 9, 'eta': 0.24501684932549128, 'gamma': 0.8089685347678612, 'scale_pos_weight': 9.91979313379138, 'min_child_weight': 8, 'max_delta_step': 1}. Best is trial 15 with value: 0.9754280748854814.
# [I 2026-06-29 10:00:28,751] Trial 27 finished with value: 0.9710473345589093 and parameters: {'lambda': 0.015592626849282695, 'alpha': 0.11667792884364582, 'subsample': 0.6981180821510822, 'colsample_bytree': 0.6760466047594682, 'max_depth': 7, 'eta': 0.14113469800208814, 'gamma': 1.898327165077156, 'scale_pos_weight': 3.0351787079496946, 'min_child_weight': 3, 'max_delta_step': 6}. Best is trial 15 with value: 0.9754280748854814.
# [I 2026-06-29 10:00:31,378] Trial 28 finished with value: 0.9758830664751027 and parameters: {'lambda': 0.004323916176367145, 'alpha': 2.2065639396840284, 'subsample': 0.9220549481750382, 'colsample_bytree': 0.6079980420802246, 'max_depth': 10, 'eta': 0.2756662322609849, 'gamma': 0.6420771552146949, 'scale_pos_weight': 1.6861522739507053, 'min_child_weight': 2, 'max_delta_step': 3}. Best is trial 28 with value: 0.9758830664751027.
# [I 2026-06-29 10:00:33,391] Trial 29 finished with value: 0.9696243149796017 and parameters: {'lambda': 0.721600820759256, 'alpha': 7.941276891381966, 'subsample': 0.903354781699183, 'colsample_bytree': 0.7667954002770645, 'max_depth': 10, 'eta': 0.2715201161500424, 'gamma': 3.6464341826445463, 'scale_pos_weight': 3.819691072052493, 'min_child_weight': 2, 'max_delta_step': 5}. Best is trial 28 with value: 0.9758830664751027.
# [I 2026-06-29 10:00:35,662] Trial 30 finished with value: 0.9715006462216488 and parameters: {'lambda': 0.0032133879939464393, 'alpha': 2.2403655459367986, 'subsample': 0.8245033687571746, 'colsample_bytree': 0.6240711706296327, 'max_depth': 7, 'eta': 0.1669128514514197, 'gamma': 0.7900598704922581, 'scale_pos_weight': 3.0274611349217695, 'min_child_weight': 2, 'max_delta_step': 3}. Best is trial 28 with value: 0.9758830664751027.
# [I 2026-06-29 10:00:37,626] Trial 31 finished with value: 0.9744786378182031 and parameters: {'lambda': 0.007437741345483094, 'alpha': 0.5400782925431374, 'subsample': 0.9605306710282879, 'colsample_bytree': 0.5802907990172551, 'max_depth': 9, 'eta': 0.2737501112529726, 'gamma': 2.081064143865212, 'scale_pos_weight': 1.589439187831445, 'min_child_weight': 1, 'max_delta_step': 2}. Best is trial 28 with value: 0.9758830664751027.
# [I 2026-06-29 10:00:40,330] Trial 32 finished with value: 0.9755166373790839 and parameters: {'lambda': 0.002211993106627868, 'alpha': 1.9874815019250809, 'subsample': 0.9164914010367992, 'colsample_bytree': 0.5217638002917809, 'max_depth': 10, 'eta': 0.2329394907293328, 'gamma': 0.8294765284151812, 'scale_pos_weight': 1.8706683133997284, 'min_child_weight': 3, 'max_delta_step': 1}. Best is trial 28 with value: 0.9758830664751027.
# [I 2026-06-29 10:00:43,044] Trial 33 finished with value: 0.9749752223393725 and parameters: {'lambda': 0.002372319111650306, 'alpha': 3.2260359126249454, 'subsample': 0.6475529592381916, 'colsample_bytree': 0.47993415448357074, 'max_depth': 10, 'eta': 0.23061190869665246, 'gamma': 0.6273323052611809, 'scale_pos_weight': 1.948134259665747, 'min_child_weight': 3, 'max_delta_step': 1}. Best is trial 28 with value: 0.9758830664751027.
# [I 2026-06-29 10:00:46,029] Trial 34 finished with value: 0.97347931079501 and parameters: {'lambda': 0.042396088387734475, 'alpha': 5.466776423728441, 'subsample': 0.9166670825782732, 'colsample_bytree': 0.533886251786799, 'max_depth': 10, 'eta': 0.1996616245287422, 'gamma': 0.1719769502842257, 'scale_pos_weight': 2.5267021554869444, 'min_child_weight': 2, 'max_delta_step': 4}. Best is trial 28 with value: 0.9758830664751027.
# [I 2026-06-29 10:00:48,443] Trial 35 finished with value: 0.9743156726654174 and parameters: {'lambda': 0.16430427781876963, 'alpha': 1.6288315978829961, 'subsample': 0.8549841810131811, 'colsample_bytree': 0.6238610225196896, 'max_depth': 10, 'eta': 0.27915478624788037, 'gamma': 0.8795327465166914, 'scale_pos_weight': 3.1523305996857, 'min_child_weight': 1, 'max_delta_step': 0}. Best is trial 28 with value: 0.9758830664751027.
# [I 2026-06-29 10:00:50,217] Trial 36 finished with value: 0.965430299700793 and parameters: {'lambda': 0.7366136927549247, 'alpha': 0.8942575473922427, 'subsample': 0.7841507348891296, 'colsample_bytree': 0.7037144935930452, 'max_depth': 9, 'eta': 0.21733601770824165, 'gamma': 9.870993879300524, 'scale_pos_weight': 3.9922292184694026, 'min_child_weight': 3, 'max_delta_step': 1}. Best is trial 28 with value: 0.9758830664751027.
# [I 2026-06-29 10:00:52,514] Trial 37 finished with value: 0.974213459292128 and parameters: {'lambda': 0.0020789114048362055, 'alpha': 0.0365863025694839, 'subsample': 0.8683522182611101, 'colsample_bytree': 0.46286905416509516, 'max_depth': 10, 'eta': 0.23217814658695657, 'gamma': 2.0790662686989005, 'scale_pos_weight': 2.7056029870341485, 'min_child_weight': 4, 'max_delta_step': 3}. Best is trial 28 with value: 0.9758830664751027.
# [I 2026-06-29 10:00:54,619] Trial 38 finished with value: 0.9732039338462393 and parameters: {'lambda': 0.017299877031831536, 'alpha': 0.15923537256719525, 'subsample': 0.9160793546796411, 'colsample_bytree': 0.5153857432248078, 'max_depth': 9, 'eta': 0.20742465511090183, 'gamma': 3.049996919069586, 'scale_pos_weight': 2.172938674391423, 'min_child_weight': 2, 'max_delta_step': 7}. Best is trial 28 with value: 0.9758830664751027.
# [I 2026-06-29 10:00:58,212] Trial 39 finished with value: 0.9624915903957434 and parameters: {'lambda': 0.0015756250286303951, 'alpha': 3.1629023653469877, 'subsample': 0.5774414575387974, 'colsample_bytree': 0.4107089455700784, 'max_depth': 10, 'eta': 0.11308465417741503, 'gamma': 0.12738475094810475, 'scale_pos_weight': 5.832324670778305, 'min_child_weight': 1, 'max_delta_step': 4}. Best is trial 28 with value: 0.9758830664751027.
# [I 2026-06-29 10:01:00,154] Trial 40 finished with value: 0.9701152511504639 and parameters: {'lambda': 0.041694821751228246, 'alpha': 1.2185114464829163, 'subsample': 0.806060370995649, 'colsample_bytree': 0.5933551184929746, 'max_depth': 8, 'eta': 0.1757739386016391, 'gamma': 5.876489742170955, 'scale_pos_weight': 1.5712318966869385, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 28 with value: 0.9758830664751027.
# [I 2026-06-29 10:01:02,286] Trial 41 finished with value: 0.9751961594637306 and parameters: {'lambda': 0.005756420555832611, 'alpha': 0.44399691828837573, 'subsample': 0.9898843169890073, 'colsample_bytree': 0.5568885464354253, 'max_depth': 9, 'eta': 0.2527425408763213, 'gamma': 1.2881332067856035, 'scale_pos_weight': 1.2610507183735002, 'min_child_weight': 6, 'max_delta_step': 2}. Best is trial 28 with value: 0.9758830664751027.
# [I 2026-06-29 10:01:04,584] Trial 42 finished with value: 0.9754867647479607 and parameters: {'lambda': 0.0010471469660509, 'alpha': 0.27079747322678643, 'subsample': 0.9678605082138072, 'colsample_bytree': 0.5621659267766149, 'max_depth': 10, 'eta': 0.26143382744817983, 'gamma': 1.4734781293497767, 'scale_pos_weight': 2.411732550546689, 'min_child_weight': 4, 'max_delta_step': 1}. Best is trial 28 with value: 0.9758830664751027.
# [I 2026-06-29 10:01:07,439] Trial 43 finished with value: 0.9760875685705366 and parameters: {'lambda': 0.0011147691564660869, 'alpha': 0.11695620689315664, 'subsample': 0.8995471958485353, 'colsample_bytree': 0.6590663416917384, 'max_depth': 10, 'eta': 0.2641963174641028, 'gamma': 0.5769135496887328, 'scale_pos_weight': 2.4563872814582597, 'min_child_weight': 4, 'max_delta_step': 1}. Best is trial 43 with value: 0.9760875685705366.
# [I 2026-06-29 10:01:10,127] Trial 44 finished with value: 0.9762190877431843 and parameters: {'lambda': 0.0010324410704418978, 'alpha': 0.11143489373971745, 'subsample': 0.957009061263769, 'colsample_bytree': 0.6433953156063522, 'max_depth': 10, 'eta': 0.2859230810343099, 'gamma': 0.6044388415941644, 'scale_pos_weight': 2.5643210239633873, 'min_child_weight': 4, 'max_delta_step': 1}. Best is trial 44 with value: 0.9762190877431843.
# [I 2026-06-29 10:01:12,182] Trial 45 finished with value: 0.9743305890506614 and parameters: {'lambda': 0.001045438463165369, 'alpha': 0.10768533300934767, 'subsample': 0.9020399745615011, 'colsample_bytree': 0.6630648165698602, 'max_depth': 10, 'eta': 0.2869842163622588, 'gamma': 1.9592734693342004, 'scale_pos_weight': 2.428231648872104, 'min_child_weight': 4, 'max_delta_step': 1}. Best is trial 44 with value: 0.9762190877431843.
# [I 2026-06-29 10:01:13,634] Trial 46 finished with value: 0.9581210644961841 and parameters: {'lambda': 0.0015494199684312248, 'alpha': 0.15633862986599228, 'subsample': 0.9634280160443905, 'colsample_bytree': 0.6835233536892064, 'max_depth': 3, 'eta': 0.2655078237018752, 'gamma': 8.444178452707426, 'scale_pos_weight': 3.287186885095881, 'min_child_weight': 4, 'max_delta_step': 0}. Best is trial 44 with value: 0.9762190877431843.
# [I 2026-06-29 10:01:15,510] Trial 47 finished with value: 0.9640787513245516 and parameters: {'lambda': 0.0032952126591892093, 'alpha': 0.024525673629534225, 'subsample': 0.8816971395766303, 'colsample_bytree': 0.6440094226504423, 'max_depth': 5, 'eta': 0.2917371869701627, 'gamma': 0.6431560314534835, 'scale_pos_weight': 7.958417671709079, 'min_child_weight': 4, 'max_delta_step': 1}. Best is trial 44 with value: 0.9762190877431843.
# [I 2026-06-29 10:01:17,351] Trial 48 finished with value: 0.9733786730735701 and parameters: {'lambda': 0.0010114374344462657, 'alpha': 0.010326169497168443, 'subsample': 0.9633614215998184, 'colsample_bytree': 0.7352276484061534, 'max_depth': 9, 'eta': 0.2769333281976257, 'gamma': 2.373494675412238, 'scale_pos_weight': 2.7198547894443053, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 44 with value: 0.9762190877431843.
# [I 2026-06-29 10:01:19,437] Trial 49 finished with value: 0.9735238436601219 and parameters: {'lambda': 0.002169276391238714, 'alpha': 0.7478982699751807, 'subsample': 0.9070056252382597, 'colsample_bytree': 0.8042808241247317, 'max_depth': 8, 'eta': 0.29957645441864544, 'gamma': 1.6693883404425973, 'scale_pos_weight': 4.099077277089777, 'min_child_weight': 5, 'max_delta_step': 1}. Best is trial 44 with value: 0.9762190877431843.

# %%
print('Best trial:')
trial=study_xgb.best_trial
print('  F1-score: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
    print('   {}: {}'.format(key, value))
    
best_params=study_xgb.best_params
best_model_xgb=XGBClassifier(**best_params)
best_model_xgb.fit(X_train_smt,y_train_smt)

# Evaluate on the test set
y_pred=best_model_xgb.predict(X_test_encoded)

report=classification_report(y_test,y_pred)
print(report)
# Out:
# Best trial:
#   F1-score: 0.9762190877431843
#   Params:
#    lambda: 0.0010324410704418978
#    alpha: 0.11143489373971745
#    subsample: 0.957009061263769
#    colsample_bytree: 0.6433953156063522
#    max_depth: 10
#    eta: 0.2859230810343099
#    gamma: 0.6044388415941644
#    scale_pos_weight: 2.5643210239633873
#    min_child_weight: 4
#    max_delta_step: 1
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     11423
#            1       0.72      0.86      0.78      1074
#
#     accuracy                           0.96     12497
#    macro avg       0.85      0.91      0.88     12497
# weighted avg       0.96      0.96      0.96     12497

# %% [markdown]
# ## Model Evaluation:ROC/AUC

# %%
y_pred=best_model_logistic.predict(X_test_encoded)
report=classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11423
#            1       0.56      0.94      0.70      1074
#
#     accuracy                           0.93     12497
#    macro avg       0.77      0.94      0.83     12497
# weighted avg       0.96      0.93      0.94     12497

# %%
from sklearn.metrics import roc_curve

probabilities=best_model_logistic.predict_proba(X_test_encoded)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,probabilities)

fpr[:5],tpr[:5],thresholds[:5]
# Out:
# (array([0.        , 0.        , 0.        , 0.00008754, 0.00008754]),
#  array([0.        , 0.0009311 , 0.16201117, 0.16201117, 0.17690875]),
#  array([       inf, 1.        , 0.99941617, 0.99941566, 0.99930065]))

# %%
from sklearn.metrics import auc

area=auc(fpr,tpr)
area
# Out:
# np.float64(0.9836851098057415)

# %%
plt.figure()
plt.plot(fpr,tpr,color='darkorange',lw=2,label='ROC curve (area = %0.2f)' % area)
plt.plot([0, 1],[0, 1],color='navy',lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Model Evaluation: Rankordering,KS statistic,Gini coeff

# %%
probabilities=best_model_logistic.predict_proba(X_test_encoded)[:,1]

df_eval = pd.DataFrame({
    'Default Truth':y_test,
    'Default Probability':probabilities
})
df_eval.head(3)
# Out:
#        Default Truth  Default Probability
# 19205              0                0.536
# 15514              0                0.000
# 30367              0                0.006

# %%
df_eval['Decile']=pd.qcut(df_eval['Default Probability'],10,labels=False,duplicates='drop')
df_eval.head(3)
# Out:
#        Default Truth  Default Probability  Decile
# 19205              0                0.536       8
# 15514              0                0.000       2
# 30367              0                0.006       6

# %%
df_decile=df_eval.groupby('Decile').apply(lambda x:pd.Series({
    'Minimum Probability':x['Default Probability'].min(),
    'Maximum Probability':x['Default Probability'].max(),
    'Events':x['Default Truth'].sum(),
    'Non-events':x['Default Truth'].count()-x['Default Truth'].sum(),    
}))
df_decile.reset_index(inplace=True)
df_decile
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15024\846259081.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_decile=df_eval.groupby('Decile').apply(lambda x:pd.Series({
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events
# 0       0                0.000                0.000   0.000    1250.000
# 1       1                0.000                0.000   0.000    1250.000
# 2       2                0.000                0.000   0.000    1249.000
# 3       3                0.000                0.000   0.000    1250.000
# 4       4                0.000                0.001   0.000    1250.000
# 5       5                0.001                0.005   0.000    1249.000
# 6       6                0.005                0.030   5.000    1245.000
# 7       7                0.030                0.215  11.000    1238.000
# 8       8                0.215                0.818 159.000    1091.000
# 9       9                0.819                1.000 899.000     351.000

# %%
df_decile['Event Rate']=df_decile['Events']*100/(df_decile['Events']+df_decile['Non-events'])
df_decile['Non-event Rate']=df_decile['Non-events']*100 /(df_decile['Events']+df_decile['Non-events'])
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       0                0.000                0.000   0.000    1250.000
# 1       1                0.000                0.000   0.000    1250.000
# 2       2                0.000                0.000   0.000    1249.000
# 3       3                0.000                0.000   0.000    1250.000
# 4       4                0.000                0.001   0.000    1250.000
# 5       5                0.001                0.005   0.000    1249.000
# 6       6                0.005                0.030   5.000    1245.000
# 7       7                0.030                0.215  11.000    1238.000
# 8       8                0.215                0.818 159.000    1091.000
# 9       9                0.819                1.000 899.000     351.000
#
#    Event Rate  Non-event Rate
# 0       0.000         100.000
# 1       0.000         100.000
# 2       0.000         100.000
# 3       0.000         100.000
# 4       0.000         100.000
# 5       0.000         100.000
# 6       0.400          99.600
# 7       0.881          99.119
# 8      12.720          87.280
# 9      71.920          28.080

# %%
df_decile=df_decile.sort_values(by='Decile',ascending=False).reset_index(drop=True)
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.819                1.000 899.000     351.000
# 1       8                0.215                0.818 159.000    1091.000
# 2       7                0.030                0.215  11.000    1238.000
# 3       6                0.005                0.030   5.000    1245.000
# 4       5                0.001                0.005   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate
# 0      71.920          28.080
# 1      12.720          87.280
# 2       0.881          99.119
# 3       0.400          99.600
# 4       0.000         100.000
# 5       0.000         100.000
# 6       0.000         100.000
# 7       0.000         100.000
# 8       0.000         100.000
# 9       0.000         100.000

# %%
df_decile['Cum Events']= df_decile['Events'].cumsum()
df_decile['Cum Non-events']= df_decile['Non-events'].cumsum()
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.819                1.000 899.000     351.000
# 1       8                0.215                0.818 159.000    1091.000
# 2       7                0.030                0.215  11.000    1238.000
# 3       6                0.005                0.030   5.000    1245.000
# 4       5                0.001                0.005   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events
# 0      71.920          28.080     899.000         351.000
# 1      12.720          87.280    1058.000        1442.000
# 2       0.881          99.119    1069.000        2680.000
# 3       0.400          99.600    1074.000        3925.000
# 4       0.000         100.000    1074.000        5174.000
# 5       0.000         100.000    1074.000        6424.000
# 6       0.000         100.000    1074.000        7674.000
# 7       0.000         100.000    1074.000        8923.000
# 8       0.000         100.000    1074.000       10173.000
# 9       0.000         100.000    1074.000       11423.000

# %%
df_decile['Cum Event Rate']=df_decile['Cum Events']*100/df_decile['Events'].sum()
df_decile['Cum Non-event Rate']=df_decile['Cum Non-events']*100 / df_decile['Non-events'].sum()
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.819                1.000 899.000     351.000
# 1       8                0.215                0.818 159.000    1091.000
# 2       7                0.030                0.215  11.000    1238.000
# 3       6                0.005                0.030   5.000    1245.000
# 4       5                0.001                0.005   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events  Cum Event Rate  \
# 0      71.920          28.080     899.000         351.000          83.706
# 1      12.720          87.280    1058.000        1442.000          98.510
# 2       0.881          99.119    1069.000        2680.000          99.534
# 3       0.400          99.600    1074.000        3925.000         100.000
# 4       0.000         100.000    1074.000        5174.000         100.000
# 5       0.000         100.000    1074.000        6424.000         100.000
# 6       0.000         100.000    1074.000        7674.000         100.000
# 7       0.000         100.000    1074.000        8923.000         100.000
# 8       0.000         100.000    1074.000       10173.000         100.000
# 9       0.000         100.000    1074.000       11423.000         100.000
#
#    Cum Non-event Rate
# 0               3.073
# 1              12.624
# 2              23.461
# 3              34.361
# 4              45.295
# 5              56.237
# 6              67.180
# 7              78.114
# 8              89.057
# 9             100.000

# %%
df_decile['KS']=abs(df_decile['Cum Event Rate']-df_decile['Cum Non-event Rate'])
df_decile
# Out:
#    Decile  Minimum Probability  Maximum Probability  Events  Non-events  \
# 0       9                0.819                1.000 899.000     351.000
# 1       8                0.215                0.818 159.000    1091.000
# 2       7                0.030                0.215  11.000    1238.000
# 3       6                0.005                0.030   5.000    1245.000
# 4       5                0.001                0.005   0.000    1249.000
# 5       4                0.000                0.001   0.000    1250.000
# 6       3                0.000                0.000   0.000    1250.000
# 7       2                0.000                0.000   0.000    1249.000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events  Cum Event Rate  \
# 0      71.920          28.080     899.000         351.000          83.706
# 1      12.720          87.280    1058.000        1442.000          98.510
# 2       0.881          99.119    1069.000        2680.000          99.534
# 3       0.400          99.600    1074.000        3925.000         100.000
# 4       0.000         100.000    1074.000        5174.000         100.000
# 5       0.000         100.000    1074.000        6424.000         100.000
# 6       0.000         100.000    1074.000        7674.000         100.000
# 7       0.000         100.000    1074.000        8923.000         100.000
# 8       0.000         100.000    1074.000       10173.000         100.000
# 9       0.000         100.000    1074.000       11423.000         100.000
#
#    Cum Non-event Rate     KS
# 0               3.073 80.633
# 1              12.624 85.887
# 2              23.461 76.073
# 3              34.361 65.639
# 4              45.295 54.705
# 5              56.237 43.763
# 6              67.180 32.820
# 7              78.114 21.886
# 8              89.057 10.943
# 9             100.000  0.000

# %%
gini_coefficient=2*area-1

print("AUC:",area)
print("Gini Coefficient:",gini_coefficient)
# Out:
# AUC: 0.9836851098057415
# Gini Coefficient: 0.9673702196114831

# %%
#Finalizing the model:
final_model=best_model_logistic
feature_importance=final_model.coef_[0]

# Create a DataFrame for easier handling
coef_df=pd.DataFrame(feature_importance,index=X_train_encoded.columns,columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df=coef_df.sort_values(by='Coefficients',ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'],color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Logistic Regression')
plt.show()

# %% [markdown]
# ## Saving the model:

# %%
X_test_encoded.head(2)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 19205 0.346               0.755                    0.333
# 15514 0.481               0.226                    1.000
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 19205                     0.990           0.550              0.000
# 15514                     0.323           0.220              0.000
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 19205                    0.000                  True                  False
# 15514                    0.000                  True                  False
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 19205                   False               True                  False
# 15514                    True              False                  False
#
#        loan_type_Unsecured
# 19205                False
# 15514                False

# %%
X_test_encoded.columns
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'residence_type_Owned',
#        'residence_type_Rented', 'loan_purpose_Education', 'loan_purpose_Home',
#        'loan_purpose_Personal', 'loan_type_Unsecured'],
#       dtype='object')

# %%
cols_to_scale
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
X_train_encoded.columns
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'residence_type_Owned',
#        'residence_type_Rented', 'loan_purpose_Education', 'loan_purpose_Home',
#        'loan_purpose_Personal', 'loan_type_Unsecured'],
#       dtype='object')

# %%
from joblib import dump

model_data = {
    'model': final_model,
    'features': X_train_encoded.columns,
    'scaler': scaler,
    'cols_to_scale': cols_to_scale
}
dump(model_data,'artifacts/model_data.joblib')
# Out:
# ['artifacts/model_data.joblib']

# %%
final_model.coef_, final_model.intercept_
# Out:
# (array([[-0.03745768,  0.63112945,  1.17115767, 15.86797013, 17.23398997,
#          13.65466713,  2.04561537, -1.83330866,  1.84364406,  1.01292672,
#          -3.39564141,  1.04850334,  1.04850334]]),
#  array([-20.6733514]))
